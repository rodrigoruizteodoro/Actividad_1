# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("Exportaciones.csv")
df.info()
df

# %%
#Filtro A
#Filtro por objeto - Columnas
A1=df[df["iso3"]=="aus"]
A1
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim   g_energy  \
# 54     aus  1997     primaryagr      5884.880      24.2051     5.9438
# 55     aus  1997      otherprim        33.194    3168.7500   220.4520
# 56     aus  1997         energy       264.191     327.3620  8225.6200
# 57     aus  1997      procfoods       122.243      21.4416     4.3458
# 58     aus  1997     bevtobacco         2.955       2.4399     0.6804
# ...    ...   ...            ...           ...          ...        ...
# 10093  aus  2011        finance       644.640    1744.6800   636.6000
# 10094  aus  2011      insurance       104.050     266.9600    71.3900
# 10095  aus  2011         obsict      1389.730    6485.8800  2022.5700
# 10096  aus  2011      oconsumer        80.830     367.5400   118.6200
# 10097  aus  2011      oservices       124.840     579.3500   192.5000
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
#Filtro para ordenar los datos
A2 = df [df["h_insurance"]>0.5]
A2
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim   g_energy  \
# 29     arg  1997         energy      282.7920       1.9522  4426.8600
# 48     arg  1997   communcation       30.1041       0.1865    13.2494
# 49     arg  1997        finance      239.0100       0.9834   150.3820
# 50     arg  1997      insurance       33.6523       0.1945    18.3172
# 51     arg  1997         obsict      172.1130       1.8889   125.9700
# ...    ...   ...            ...           ...          ...        ...
# 13168  zmb  2011   distribution      370.6800     200.5300    72.9600
# 13171  zmb  2011        finance       25.2200      14.7300    12.0200
# 13172  zmb  2011      insurance        2.1500       1.2900     0.8900
# 13199  zwe  2011      insurance        2.9000       0.0400     0.0300
# 13202  zwe  2011      oservices       12.1400       1.0900     0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
#Se aplican ambos filtros
AF=df[(df["h_insurance"]>0.5)& (df["iso3"]=="aus")]
AF
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim   g_energy  \
# 56     aus  1997         energy      264.1910     327.3620  8225.6200
# 63     aus  1997       paperpub       79.4958      42.9939    27.4799
# 73     aus  1997   distribution      560.1380     330.4000   166.1190
# 74     aus  1997      transport      332.4430     165.4730   160.8570
# 75     aus  1997   communcation      135.5080     107.7990    53.3749
# ...    ...   ...            ...           ...          ...        ...
# 10093  aus  2011        finance      644.6400    1744.6800   636.6000
# 10094  aus  2011      insurance      104.0500     266.9600    71.3900
# 10095  aus  2011         obsict     1389.7300    6485.8800  2022.5700
# 10096  aus  2011      oconsumer       80.8300     367.5400   118.6200
# 10097  aus  2011      oservices      124.8400     579.3500   192.5000
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
#Filtro B
#Se filtra la base de datos por "Sector_Gmatrix"= insurance
b1=df[df["sector_GMatrix"]=="insurance"]
b1
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 23     alb  1997      insurance        0.2156       0.0586    0.9468
# 50     arg  1997      insurance       33.6523       0.1945   18.3172
# 77     aus  1997      insurance      102.2560      13.0391    6.3998
# 104    aut  1997      insurance        1.1619       0.6656    1.0548
# 131    bel  1997      insurance        5.8961       0.8964    0.6508
# ...    ...   ...            ...           ...          ...       ...
# 13091  ven  2011      insurance       13.2100       5.2000   34.9900
# 13118  vnm  2011      insurance        2.2900       3.0200    2.1900
# 13145  zaf  2011      insurance      387.2100     294.9800  148.8600
# 13172  zmb  2011      insurance        2.1500       1.2900    0.8900
# 13199  zwe  2011      insurance        2.9000       0.0400    0.0300
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
#Filtro para mostrar datos mayores a 7
B2 = df [df["g_procfoods"]>7]
B2
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 0      alb  1997     primaryagr       93.3774       0.0143    0.2158
# 2      alb  1997         energy       12.8071       3.0441  195.5730
# 3      alb  1997      procfoods        0.8223       0.0041    0.0706
# 19     alb  1997   distribution        5.4262       0.3115    7.8977
# 27     arg  1997     primaryagr    13518.8000       0.1668    2.8926
# ...    ...   ...            ...           ...          ...       ...
# 13189  zwe  2011      fabmetals        2.1400       2.8200    1.2900
# 13195  zwe  2011   distribution       38.2800       8.1100    4.1500
# 13196  zwe  2011      transport       13.4400       7.2500    3.8900
# 13200  zwe  2011         obsict       18.5100       0.4300    0.3700
# 13202  zwe  2011      oservices       12.1400       1.0900    0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
#Filtro B con la condición &
BF=df[(df["g_procfoods"]>7)& (df["sector_GMatrix"]=="insurance")]
BF
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 50     arg  1997      insurance       33.6523       0.1945   18.3172
# 77     aus  1997      insurance      102.2560      13.0391    6.3998
# 104    aut  1997      insurance        1.1619       0.6656    1.0548
# 131    bel  1997      insurance        5.8961       0.8964    0.6508
# 158    bgd  1997      insurance        1.8448       2.4555    0.1200
# ...    ...   ...            ...           ...          ...       ...
# 13064  usa  2011      insurance      759.4300     101.2600  657.7600
# 13091  ven  2011      insurance       13.2100       5.2000   34.9900
# 13118  vnm  2011      insurance        2.2900       3.0200    2.1900
# 13145  zaf  2011      insurance      387.2100     294.9800  148.8600
# 13172  zmb  2011      insurance        2.1500       1.2900    0.8900
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
#Filtro C
#Se toman las exportaciones entre un rango que va de mayor o igual a 
#1997 y menores o iguales a 2005
C1=df[(df["year"] >= 1997) & (df["year"] <=2005)]
C1

# %%
#Filtro D
#Se toman todos los valores de la columna "VXsharefwd" mayores a 0.5 y "VXsharebwd" menores
#a 0.5
D1=df[(df["VXsharefwd"] > 0.5) & (df["VXsharebwd"] < 0.5)]
D1
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim   g_energy  \
# 2      alb  1997         energy       12.8071       3.0441   195.5730
# 3591   uga  2001     primaryagr     2410.5800       2.9207     1.4033
# 4023   ben  2004     primaryagr      782.2470       0.2940     0.0006
# 5672   moz  2004         energy        0.5997       1.2089   585.2830
# 6671   ukr  2004         energy      502.6150     479.4450  9272.7200
# 7101   ben  2007     primaryagr      808.7770       0.3887     0.0024
# 8750   moz  2007         energy        1.3909       0.7836  1119.7600
# 9928   zmb  2007   distribution      318.3260     220.2380    73.9112
# 13168  zmb  2011   distribution      370.6800     200.5300    72.9600
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# 2          19.9136        0.5700      7.7880     21.7902  ...     0.0188
# 3591      116.9660       70.6304      3.8296      0.5233  ...     0.0024
# ...

# %%
#Filtro E
E1 = df[(df["iso3"]=="kor")|(df["iso3"]=="tha")|(df["iso3"]=="phl")|(df["iso3"]=="ven")|(df["iso3"]=="deu")]
E1
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim   g_energy  \
# 432    deu  1997     primaryagr     5865.0500      43.3788     0.3436
# 433    deu  1997      otherprim       20.8830    1753.7200     0.4747
# 434    deu  1997         energy      246.6800      61.8903   535.6640
# 435    deu  1997      procfoods      494.4210      25.5599     0.7977
# 436    deu  1997     bevtobacco       13.7084       4.6927     0.5570
# ...    ...   ...            ...           ...          ...        ...
# 13090  ven  2011        finance      107.2300      45.9500  1499.9100
# 13091  ven  2011      insurance       13.2100       5.2000    34.9900
# 13092  ven  2011         obsict      219.1000     177.4700  1517.3600
# 13093  ven  2011      oconsumer        9.5800       9.0200    40.9600
# 13094  ven  2011      oservices       16.2800      14.1900    66.5200
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
E2=E1[E1["g_textiles"] > 1]
E2
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim   g_energy  \
# 432    deu  1997     primaryagr     5865.0500      43.3788     0.3436
# 433    deu  1997      otherprim       20.8830    1753.7200     0.4747
# 434    deu  1997         energy      246.6800      61.8903   535.6640
# 435    deu  1997      procfoods      494.4210      25.5599     0.7977
# 436    deu  1997     bevtobacco       13.7084       4.6927     0.5570
# ...    ...   ...            ...           ...          ...        ...
# 13090  ven  2011        finance      107.2300      45.9500  1499.9100
# 13091  ven  2011      insurance       13.2100       5.2000    34.9900
# 13092  ven  2011         obsict      219.1000     177.4700  1517.3600
# 13093  ven  2011      oconsumer        9.5800       9.0200    40.9600
# 13094  ven  2011      oservices       16.2800      14.1900    66.5200
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
#Las 100 exportaciones de "iso3:tha, kor, phl, ven y deu" con "g_textiles" mayor a 1 y "g_clothing" menor a 1
E3=E2[E2["g_clothing"] < 1]
E3
# Out:
# Empty DataFrame
# Columns: [iso3, year, sector_GMatrix, g_primaryagr, g_otherprim, g_energy, g_procfoods, g_bevtobacco, g_textiles, g_clothing, g_leather, g_lumber, g_paperpub, g_chemicals, g_nonmetmin, g_metals, g_fabmetals, g_transpequip, g_machinery, g_othermanuf, g_water, g_construction, g_distribution, g_transport, g_communcation, g_finance, g_insurance, g_obsict, g_oconsumer, g_oservices, sector_HMatrix, h_primaryagr, h_otherprim, h_energy, h_procfoods, h_bevtobacco, h_textiles, h_clothing, h_leather, h_lumber, h_paperpub, h_chemicals, h_nonmetmin, h_metals, h_fabmetals, h_transpequip, h_machinery, h_othermanuf, h_water, h_construction, h_distribution, h_transport, h_communcation, h_finance, h_insurance, h_obsict, h_oconsumer, h_oservices, DomVAshare, GXshare, DXshare, VXsharefwd, VXsharebwd]
# Index: []
#
# [0 rows x 63 columns]

# %%
#Filtro F
#Las exportaciones pertenecientes al año 2004
# y los "h_oservices" mayores a 10
F1=df[df["year"] == 2004]
F1
# Out:
#      iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 3807  alb  2004     primaryagr      517.8180       0.1213    0.4691
# 3808  alb  2004      otherprim        0.5632      31.6661    0.2165
# 3809  alb  2004         energy       12.8485       2.3180  216.5920
# 3810  alb  2004      procfoods        5.5821       0.0247    0.1110
# 3811  alb  2004     bevtobacco        0.0202       0.0022    0.0062
# ...   ...   ...            ...           ...          ...       ...
# 6880  zwe  2004        finance       12.9971       0.2822    0.2540
# 6881  zwe  2004      insurance        2.3389       0.0342    0.0250
# 6882  zwe  2004         obsict       14.5142       0.3718    0.3170
# 6883  zwe  2004      oconsumer        2.3766       0.0570    0.0672
# 6884  zwe  2004      oservices        9.4795       0.9173    0.5526
#
#       g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# 3807     195.3910        4.7032      2.8133      7.3839  ...     0.0304
# ...

# %%
F2=F1[F1["h_oservices"] > 10]
F2
# Out:
#      iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 3833  alb  2004      oservices        0.2913       0.1102    0.1467
# 3860  are  2004      oservices        0.1888       0.0584   15.8087
# 3885  arg  2004         obsict      251.8390       6.4964   83.9202
# 3887  arg  2004      oservices      202.6470       5.3857   76.9778
# 3914  arm  2004      oservices        2.5615       1.0366    0.6777
# ...   ...   ...            ...           ...          ...       ...
# 6827  zaf  2004      insurance      235.5240     133.2500  132.4490
# 6828  zaf  2004         obsict      272.1790     233.8180  151.5080
# 6830  zaf  2004      oservices       63.6928      25.9981    5.6810
# 6857  zmb  2004      oservices        0.5410       1.0682    5.1792
# 6884  zwe  2004      oservices        9.4795       0.9173    0.5526
#
#       g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# 3833       0.3305        0.0156      0.1665      0.1973  ...     0.0336
# ...

# %%
#Filtro G
#Se muestan todas las exportaciones de "sector_GMatrix" menos "machinery"

G1=df[~(df["sector_GMatrix"] == "machinery")]
G1
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 0      alb  1997     primaryagr       93.3774       0.0143    0.2158
# 1      alb  1997      otherprim        0.0521       5.7779    0.0979
# 2      alb  1997         energy       12.8071       3.0441  195.5730
# 3      alb  1997      procfoods        0.8223       0.0041    0.0706
# 4      alb  1997     bevtobacco        0.0022       0.0003    0.0036
# ...    ...   ...            ...           ...          ...       ...
# 13198  zwe  2011        finance       15.7700       0.3200    0.2900
# 13199  zwe  2011      insurance        2.9000       0.0400    0.0300
# 13200  zwe  2011         obsict       18.5100       0.4300    0.3700
# 13201  zwe  2011      oconsumer        3.0600       0.0700    0.0800
# 13202  zwe  2011      oservices       12.1400       1.0900    0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...

# %%
#Filtro H
#e muestan todas las exportaciones de "DXshare" menos las que sean mayores a 0.5
H1=df[~(df["DXshare"] > 0.5)]
H1
# Out:
#       iso3  year sector_GMatrix  g_primaryagr  g_otherprim  g_energy  \
# 0      alb  1997     primaryagr       93.3774       0.0143    0.2158
# 1      alb  1997      otherprim        0.0521       5.7779    0.0979
# 3      alb  1997      procfoods        0.8223       0.0041    0.0706
# 4      alb  1997     bevtobacco        0.0022       0.0003    0.0036
# 5      alb  1997       textiles        0.0082       0.0004    0.0028
# ...    ...   ...            ...           ...          ...       ...
# 13198  zwe  2011        finance       15.7700       0.3200    0.2900
# 13199  zwe  2011      insurance        2.9000       0.0400    0.0300
# 13200  zwe  2011         obsict       18.5100       0.4300    0.3700
# 13201  zwe  2011      oconsumer        3.0600       0.0700    0.0800
# 13202  zwe  2011      oservices       12.1400       1.0900    0.6800
#
#        g_procfoods  g_bevtobacco  g_textiles  g_clothing  ...  h_finance  \
# ...
